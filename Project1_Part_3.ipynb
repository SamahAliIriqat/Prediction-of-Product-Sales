# %% [markdown]
# <a href="https://colab.research.google.com/github/SamahAliIriqat/Prediction-of-Product-Sales/blob/main/Project1_Part_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
sales_prediction = "/content/drive/MyDrive/CodingDojo/01-Fundamentals/Week02/sales_predictions_2023.csv"

# %%
df = pd.read_csv(sales_prediction)

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# numerical features in df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# Histograms to view the distributions of Item_Weight
sns.histplot(df['Item_Weight'])
# Out:
# <Axes: xlabel='Item_Weight', ylabel='Count'>

# %%
# Histograms to view the distributions of Item_Visibility
sns.histplot(df['Item_Visibility'])
# Out:
# <Axes: xlabel='Item_Visibility', ylabel='Count'>

# %%
# Histograms to view the distributions of Item_MRP
sns.histplot(df['Item_MRP'])
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Count'>

# %%
# Histograms to view the distributions of Outlet_Establishment_Year
sns.histplot(df['Outlet_Establishment_Year'])
# Out:
# <Axes: xlabel='Outlet_Establishment_Year', ylabel='Count'>

# %%
# Histograms to view the distributions of Item_Outlet_Sales
sns.histplot(df['Item_Outlet_Sales'])
# Out:
# <Axes: xlabel='Item_Outlet_Sales', ylabel='Count'>

# %%
# Countplots to view the frequency of each class of categorial features in your dataset
sns.countplot(x='Item_Fat_Content', data=df)
# Out:
# <Axes: xlabel='Item_Fat_Content', ylabel='count'>

# %%
ax = sns.countplot(x='Item_Type', data=df)
ax.tick_params(axis='x', rotation = 90);

# %%
sns.countplot(x='Outlet_Size', data=df)
# Out:
# <Axes: xlabel='Outlet_Size', ylabel='count'>

# %%
sns.countplot(x='Outlet_Location_Type', data=df)
# Out:
# <Axes: xlabel='Outlet_Location_Type', ylabel='count'>

# %%
ax = sns.countplot(x='Outlet_Type', data=df)
ax.tick_params(axis='x', rotation = 90);

# %%
# Heatmap to view the correlation between features in df
corr = df.corr(numeric_only = True)
sns.heatmap(corr, cmap = 'coolwarm', annot = True);
